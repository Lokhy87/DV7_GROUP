# %%
# BIBLIOTECAS
import pandas as pd
import unicodedata

# %%
pd.set_option('display.max_rows', None)  # Muestra todas las filas
pd.set_option('display.max_columns', None)  # Muestra todas las columnas

# %% [markdown]
# BASE DATOS 1a y 2da DIVISION

# %% [markdown]
# LA LIGA

# %%
df_primera = pd.read_csv('Jugadores_LaLiga.csv')
df_primera
# Out:
#                Nombre           Equipo    Liga Fecha Fichaje Contrato Hasta  \
# 0    Thibaut Courtois      Real Madrid  LaLiga    09/08/2018     30/06/2026
# 1        Andriy Lunin      Real Madrid  LaLiga    01/07/2018     30/06/2030
# 2        Éder Militão      Real Madrid  LaLiga    01/07/2019     30/06/2028
# 3     Antonio Rüdiger      Real Madrid  LaLiga    01/07/2022     30/06/2026
# 4         David Alaba      Real Madrid  LaLiga    01/07/2021     30/06/2026
# ..                ...              ...     ...           ...            ...
# 496      Amath Ndiaye  Real Valladolid  LaLiga    01/07/2024     30/06/2027
# 497      Iván Sánchez  Real Valladolid  LaLiga    01/07/2022     30/06/2025
# 498     Juanmi Latasa  Real Valladolid  LaLiga    14/08/2024     30/06/2029
# 499     Mamadou Sylla  Real Valladolid  LaLiga    01/09/2023     30/06/2026
# 500      Marcos André  Real Valladolid  LaLiga    29/08/2023     30/06/2029
#
# ...

# %%
df_primera.columns = df_primera.columns.str.normalize('NFD').str.encode('ascii', 'ignore').str.decode('utf-8')
df_primera
# Out:
#                Nombre           Equipo    Liga Fecha Fichaje Contrato Hasta  \
# 0    Thibaut Courtois      Real Madrid  LaLiga    09/08/2018     30/06/2026
# 1        Andriy Lunin      Real Madrid  LaLiga    01/07/2018     30/06/2030
# 2        Éder Militão      Real Madrid  LaLiga    01/07/2019     30/06/2028
# 3     Antonio Rüdiger      Real Madrid  LaLiga    01/07/2022     30/06/2026
# 4         David Alaba      Real Madrid  LaLiga    01/07/2021     30/06/2026
# ..                ...              ...     ...           ...            ...
# 496      Amath Ndiaye  Real Valladolid  LaLiga    01/07/2024     30/06/2027
# 497      Iván Sánchez  Real Valladolid  LaLiga    01/07/2022     30/06/2025
# 498     Juanmi Latasa  Real Valladolid  LaLiga    14/08/2024     30/06/2029
# 499     Mamadou Sylla  Real Valladolid  LaLiga    01/09/2023     30/06/2026
# 500      Marcos André  Real Valladolid  LaLiga    29/08/2023     30/06/2029
#
# ...

# %% [markdown]
# HYPERMOTION

# %%
df_segunda = pd.read_csv('Jugadores_LigaHypermotion.csv')
df_segunda
# Out:
#                  Nombre       Equipo         Liga Fecha Fichaje  \
# 0        Luís Maximiano   UD Almería  2ª División    01/07/2024
# 1     Fernando Martínez   UD Almería  2ª División    05/07/2017
# 2        Edgar González   UD Almería  2ª División    06/07/2023
# 3                 Chumi   UD Almería  2ª División    10/09/2020
# 4                 Kaiky   UD Almería  2ª División    19/07/2022
# ..                  ...          ...          ...           ...
# 517          Álex Calvo  CD Mirandés  2ª División    22/08/2024
# 518        Ander Martín  CD Mirandés  2ª División    30/08/2024
# 519       Alberto Dadie  CD Mirandés  2ª División    29/08/2024
# 520  Joaquín Panichelli  CD Mirandés  2ª División    19/08/2024
# 521          Urko Izeta  CD Mirandés  2ª División    08/08/2024
#
#     Contrato Hasta Fecha Nacimiento  Lugar Nacimiento Nacionalidad  Altura  \
# 0       30/06/2029  05/01/1999 (25)          Celeirós     Portugal  1,90 m
# ...

# %%
df_segunda.columns = df_primera.columns.str.normalize('NFD').str.encode('ascii', 'ignore').str.decode('utf-8')
df_segunda
# Out:
#                  Nombre       Equipo         Liga Fecha Fichaje  \
# 0        Luís Maximiano   UD Almería  2ª División    01/07/2024
# 1     Fernando Martínez   UD Almería  2ª División    05/07/2017
# 2        Edgar González   UD Almería  2ª División    06/07/2023
# 3                 Chumi   UD Almería  2ª División    10/09/2020
# 4                 Kaiky   UD Almería  2ª División    19/07/2022
# ..                  ...          ...          ...           ...
# 517          Álex Calvo  CD Mirandés  2ª División    22/08/2024
# 518        Ander Martín  CD Mirandés  2ª División    30/08/2024
# 519       Alberto Dadie  CD Mirandés  2ª División    29/08/2024
# 520  Joaquín Panichelli  CD Mirandés  2ª División    19/08/2024
# 521          Urko Izeta  CD Mirandés  2ª División    08/08/2024
#
#     Contrato Hasta Fecha Nacimiento  Lugar Nacimiento Nacionalidad  Altura  \
# 0       30/06/2029  05/01/1999 (25)          Celeirós     Portugal  1,90 m
# ...

# %%
df_concatenado = pd.concat([df_primera, df_segunda], axis=0)
df_concatenado
# Out:
#                  Nombre       Equipo         Liga Fecha Fichaje  \
# 0      Thibaut Courtois  Real Madrid       LaLiga    09/08/2018
# 1          Andriy Lunin  Real Madrid       LaLiga    01/07/2018
# 2          Éder Militão  Real Madrid       LaLiga    01/07/2019
# 3       Antonio Rüdiger  Real Madrid       LaLiga    01/07/2022
# 4           David Alaba  Real Madrid       LaLiga    01/07/2021
# ..                  ...          ...          ...           ...
# 517          Álex Calvo  CD Mirandés  2ª División    22/08/2024
# 518        Ander Martín  CD Mirandés  2ª División    30/08/2024
# 519       Alberto Dadie  CD Mirandés  2ª División    29/08/2024
# 520  Joaquín Panichelli  CD Mirandés  2ª División    19/08/2024
# 521          Urko Izeta  CD Mirandés  2ª División    08/08/2024
#
#     Contrato Hasta Fecha Nacimiento         Lugar Nacimiento Nacionalidad  \
# 0       30/06/2026  11/05/1992 (32)                     Bree      Bélgica
# ...

# %%
df_concatenado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1023 entries, 0 to 521
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Nombre                    1023 non-null   object
#  1   Equipo                    1023 non-null   object
#  2   Liga                      1023 non-null   object
#  3   Fecha Fichaje             1023 non-null   object
#  4   Contrato Hasta            1023 non-null   object
#  5   Fecha Nacimiento          1023 non-null   object
#  6   Lugar Nacimiento          1023 non-null   object
#  7   Nacionalidad              1023 non-null   object
#  8   Altura                    1023 non-null   object
#  9   Posicion                  1023 non-null   object
#  10  Seleccion                 1023 non-null   object
#  11  Partidos Internacionales  1023 non-null   object
#  12  Goles                     1023 non-null   object
# ...

# %%
df_concatenado
# Out:
#                  Nombre       Equipo         Liga Fecha Fichaje  \
# 0      Thibaut Courtois  Real Madrid       LaLiga    09/08/2018
# 1          Andriy Lunin  Real Madrid       LaLiga    01/07/2018
# 2          Éder Militão  Real Madrid       LaLiga    01/07/2019
# 3       Antonio Rüdiger  Real Madrid       LaLiga    01/07/2022
# 4           David Alaba  Real Madrid       LaLiga    01/07/2021
# ..                  ...          ...          ...           ...
# 517          Álex Calvo  CD Mirandés  2ª División    22/08/2024
# 518        Ander Martín  CD Mirandés  2ª División    30/08/2024
# 519       Alberto Dadie  CD Mirandés  2ª División    29/08/2024
# 520  Joaquín Panichelli  CD Mirandés  2ª División    19/08/2024
# 521          Urko Izeta  CD Mirandés  2ª División    08/08/2024
#
#     Contrato Hasta Fecha Nacimiento         Lugar Nacimiento Nacionalidad  \
# 0       30/06/2026  11/05/1992 (32)                     Bree      Bélgica
# ...

# %%
df_concatenado['Edad'] = df_concatenado['Fecha Nacimiento'].str.extract(r'\((\d+)\)')

# %%
df_concatenado.head()
# Out:
#              Nombre       Equipo    Liga Fecha Fichaje Contrato Hasta  \
# 0  Thibaut Courtois  Real Madrid  LaLiga    09/08/2018     30/06/2026
# 1      Andriy Lunin  Real Madrid  LaLiga    01/07/2018     30/06/2030
# 2      Éder Militão  Real Madrid  LaLiga    01/07/2019     30/06/2028
# 3   Antonio Rüdiger  Real Madrid  LaLiga    01/07/2022     30/06/2026
# 4       David Alaba  Real Madrid  LaLiga    01/07/2021     30/06/2026
#
#   Fecha Nacimiento         Lugar Nacimiento Nacionalidad  Altura  \
# 0  11/05/1992 (32)                     Bree      Bélgica  2,00 m
# 1  11/02/1999 (25)  Krasnograd, Kharkiv ...      Ucrania  1,91 m
# 2  18/01/1998 (26)              Sertãozinho       Brasil  1,86 m
# 3  03/03/1993 (31)                   Berlin     Alemania  1,90 m
# 4  24/06/1992 (32)                     Wien      Austria  1,80 m
#
#           Posicion                Seleccion Partidos Internacionales Goles  \
# ...

# %%
df_concatenado['Fecha Nacimiento'] = df_concatenado['Fecha Nacimiento'].str.replace(r'\s*\(.*\)', '', regex=True)
df_concatenado
# Out:
#                  Nombre       Equipo         Liga Fecha Fichaje  \
# 0      Thibaut Courtois  Real Madrid       LaLiga    09/08/2018
# 1          Andriy Lunin  Real Madrid       LaLiga    01/07/2018
# 2          Éder Militão  Real Madrid       LaLiga    01/07/2019
# 3       Antonio Rüdiger  Real Madrid       LaLiga    01/07/2022
# 4           David Alaba  Real Madrid       LaLiga    01/07/2021
# ..                  ...          ...          ...           ...
# 517          Álex Calvo  CD Mirandés  2ª División    22/08/2024
# 518        Ander Martín  CD Mirandés  2ª División    30/08/2024
# 519       Alberto Dadie  CD Mirandés  2ª División    29/08/2024
# 520  Joaquín Panichelli  CD Mirandés  2ª División    19/08/2024
# 521          Urko Izeta  CD Mirandés  2ª División    08/08/2024
#
#     Contrato Hasta Fecha Nacimiento         Lugar Nacimiento Nacionalidad  \
# 0       30/06/2026       11/05/1992                     Bree      Bélgica
# ...

# %%
df_concatenado = df_concatenado[['Nombre', 'Equipo', 'Liga', 'Fecha Nacimiento', 'Edad', 'Contrato Hasta', 
             'Lugar Nacimiento', 'Nacionalidad', 'Altura', 'Posicion', 'Seleccion', 
             'Partidos Internacionales', 'Goles', 'Valor Mercado', 'Ultima Revision', 
             'Pie', 'Agente', 'Proveedor']]
df_concatenado
# Out:
#                  Nombre       Equipo         Liga Fecha Nacimiento Edad  \
# 0      Thibaut Courtois  Real Madrid       LaLiga       11/05/1992   32
# 1          Andriy Lunin  Real Madrid       LaLiga       11/02/1999   25
# 2          Éder Militão  Real Madrid       LaLiga       18/01/1998   26
# 3       Antonio Rüdiger  Real Madrid       LaLiga       03/03/1993   31
# 4           David Alaba  Real Madrid       LaLiga       24/06/1992   32
# ..                  ...          ...          ...              ...  ...
# 517          Álex Calvo  CD Mirandés  2ª División       20/02/2004   20
# 518        Ander Martín  CD Mirandés  2ª División       16/11/2000   23
# 519       Alberto Dadie  CD Mirandés  2ª División       20/07/2002   22
# 520  Joaquín Panichelli  CD Mirandés  2ª División       07/10/2002   22
# 521          Urko Izeta  CD Mirandés  2ª División       29/09/1999   25
#
#     Contrato Hasta         Lugar Nacimiento Nacionalidad  Altura  \
# ...

# %%
df_concatenado['Proveedor'].value_counts()
# Out:
# Proveedor
# Proveedor no encontrado    808
# Nike                        90
# adidas                      83
# Puma                        29
# New Balance                  4
# Mizuno                       3
# Under Armour                 2
# Joma                         2
# Sells                        1
# Lotto                        1
# Name: count, dtype: int64

# %%
# df_concatenado.to_csv('DB_Jugadores_1a_2da_Division.csv', index = False)

# %%
df_concatenado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1023 entries, 0 to 521
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Nombre                    1023 non-null   object
#  1   Equipo                    1023 non-null   object
#  2   Liga                      1023 non-null   object
#  3   Fecha Nacimiento          1023 non-null   object
#  4   Edad                      1023 non-null   object
#  5   Contrato Hasta            1023 non-null   object
#  6   Lugar Nacimiento          1023 non-null   object
#  7   Nacionalidad              1023 non-null   object
#  8   Altura                    1023 non-null   object
#  9   Posicion                  1023 non-null   object
#  10  Seleccion                 1023 non-null   object
#  11  Partidos Internacionales  1023 non-null   object
#  12  Goles                     1023 non-null   object
# ...

# %%
df_ligas_limpio = df_concatenado.drop(columns=['Nacionalidad', 'Altura', 'Seleccion', 'Partidos Internacionales', 'Goles', 'Ultima Revision', 'Pie'])
df_ligas_limpio
# Out:
#                  Nombre       Equipo         Liga Fecha Nacimiento Edad  \
# 0      Thibaut Courtois  Real Madrid       LaLiga       11/05/1992   32
# 1          Andriy Lunin  Real Madrid       LaLiga       11/02/1999   25
# 2          Éder Militão  Real Madrid       LaLiga       18/01/1998   26
# 3       Antonio Rüdiger  Real Madrid       LaLiga       03/03/1993   31
# 4           David Alaba  Real Madrid       LaLiga       24/06/1992   32
# ..                  ...          ...          ...              ...  ...
# 517          Álex Calvo  CD Mirandés  2ª División       20/02/2004   20
# 518        Ander Martín  CD Mirandés  2ª División       16/11/2000   23
# 519       Alberto Dadie  CD Mirandés  2ª División       20/07/2002   22
# 520  Joaquín Panichelli  CD Mirandés  2ª División       07/10/2002   22
# 521          Urko Izeta  CD Mirandés  2ª División       29/09/1999   25
#
#     Contrato Hasta         Lugar Nacimiento          Posicion  Valor Mercado  \
# ...

# %%
df_ligas_limpio['Valor Mercado'].value_counts()
# Out:
# Valor Mercado
# 1,00 mill. €                      65
# 500 mil €                         64
# 1,50 mill. €                      58
# 300 mil €                         58
# 200 mil €                         53
#                                   ..
# 35,00 mill. €                      1
# 11,00 mill. €                      1
# 13,00 mill. €                      1
# 25 mil €                           1
# Valor de mercado no encontrado     1
# Name: count, Length: 61, dtype: int64

# %%
df_ligas_limpio[df_ligas_limpio['Nombre'] == 'Thibaut Courtois']
# Out:
#              Nombre       Equipo    Liga Fecha Nacimiento Edad Contrato Hasta  \
# 0  Thibaut Courtois  Real Madrid  LaLiga       11/05/1992   32     30/06/2026
#
#   Lugar Nacimiento Posicion  Valor Mercado               Agente Proveedor
# 0             Bree  Portero  25,00 mill. €  Christophe Henrotay      Nike

# %%
df_ligas_limpio[df_ligas_limpio['Nombre'] == 'Ander Martín']
# Out:
#            Nombre       Equipo         Liga Fecha Nacimiento Edad  \
# 518  Ander Martín  CD Mirandés  2ª División       16/11/2000   23
#
#     Contrato Hasta  Lugar Nacimiento         Posicion Valor Mercado  \
# 518     30/06/2025  Donostia-San ...  Extremo derecho     400 mil €
#
#         Agente                Proveedor
# 518  YOU FIRST  Proveedor no encontrado

# %%
df_ligas_limpio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1023 entries, 0 to 521
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Nombre            1023 non-null   object
#  1   Equipo            1023 non-null   object
#  2   Liga              1023 non-null   object
#  3   Fecha Nacimiento  1023 non-null   object
#  4   Edad              1023 non-null   object
#  5   Contrato Hasta    1023 non-null   object
#  6   Lugar Nacimiento  1023 non-null   object
#  7   Posicion          1023 non-null   object
#  8   Valor Mercado     1023 non-null   object
#  9   Agente            1023 non-null   object
#  10  Proveedor         1023 non-null   object
# dtypes: object(11)
# memory usage: 95.9+ KB

# %%
def clean_valor_mercado(valor):
    if isinstance(valor, str):  # Verificar si el valor es un string
        valor = valor.replace("€", "").strip()
        if "mill." in valor:
            return float(valor.replace("mill.", "").replace(",", ".")) * 1_000_000
        elif "mil" in valor:
            return float(valor.replace("mil", "").replace(",", ".")) * 1_000
    return None  # Devolver None si el formato no es esperado

# Aplicar la función de limpieza y reemplazar NaN con 0 antes de convertir a enteros
df_ligas_limpio['Valor Mercado'] = df_ligas_limpio['Valor Mercado'].apply(clean_valor_mercado).fillna(0).astype(int)

# Convertir "Edad" a numérico, reemplazar NaN con 0, y luego a entero
df_ligas_limpio['Edad'] = pd.to_numeric(df_ligas_limpio['Edad'], errors='coerce').fillna(0).astype(int)

# %%
df_ligas_limpio['Valor Mercado'].head()
# Out:
# 0    25000000
# 1    25000000
# 2    60000000
# 3    25000000
# 4    15000000
# Name: Valor Mercado, dtype: int64

# %%
df_ligas_limpio.head()
# Out:
#              Nombre       Equipo    Liga Fecha Nacimiento  Edad  \
# 0  Thibaut Courtois  Real Madrid  LaLiga       11/05/1992    32
# 1      Andriy Lunin  Real Madrid  LaLiga       11/02/1999    25
# 2      Éder Militão  Real Madrid  LaLiga       18/01/1998    26
# 3   Antonio Rüdiger  Real Madrid  LaLiga       03/03/1993    31
# 4       David Alaba  Real Madrid  LaLiga       24/06/1992    32
#
#   Contrato Hasta         Lugar Nacimiento         Posicion  Valor Mercado  \
# 0     30/06/2026                     Bree          Portero       25000000
# 1     30/06/2030  Krasnograd, Kharkiv ...          Portero       25000000
# 2     30/06/2028              Sertãozinho  Defensa central       60000000
# 3     30/06/2026                   Berlin  Defensa central       25000000
# 4     30/06/2026                     Wien  Defensa central       15000000
#
#                   Agente     Proveedor
# 0    Christophe Henrotay          Nike
# 1              Gestifute        adidas
# ...

# %%
df_ligas_limpio[df_ligas_limpio['Nombre'] == 'Ander Martín']
# Out:
#            Nombre       Equipo         Liga Fecha Nacimiento  Edad  \
# 518  Ander Martín  CD Mirandés  2ª División       16/11/2000    23
#
#     Contrato Hasta  Lugar Nacimiento         Posicion  Valor Mercado  \
# 518     30/06/2025  Donostia-San ...  Extremo derecho         400000
#
#         Agente                Proveedor
# 518  YOU FIRST  Proveedor no encontrado

# %%
# df_ligas_limpio.to_csv('DB_Jugadores_columnasUtiles.csv', index = False)

# %%
df_ligas_limpio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1023 entries, 0 to 521
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Nombre            1023 non-null   object
#  1   Equipo            1023 non-null   object
#  2   Liga              1023 non-null   object
#  3   Fecha Nacimiento  1023 non-null   object
#  4   Edad              1023 non-null   int64
#  5   Contrato Hasta    1023 non-null   object
#  6   Lugar Nacimiento  1023 non-null   object
#  7   Posicion          1023 non-null   object
#  8   Valor Mercado     1023 non-null   int64
#  9   Agente            1023 non-null   object
#  10  Proveedor         1023 non-null   object
# dtypes: int64(2), object(9)
# memory usage: 95.9+ KB

# %%
df_ligas_limpio['Agente'].value_counts()
# Out:
# Agente
# Agente no encontrado                       84
# Promoesport                                51
# YOU FIRST                                  46
# Wasserman                                  41
# CAA Stellar                                37
# JV SPORTS                                  35
# IDUB GLOBAL                                26
# InterStarDeporte                           21
# LEADERBROCK                                20
# Footfeel ISM                               18
# Bahía Internacional                        17
# Miembro de su familia                      16
# Emartsoccer                                15
# MESAS SPORT                                14
# Niagara Sports ...                         14
# WAKAI SPORTS                               13
# LIAN Sports Group                          12
# CAA Base Ltd                               11
# Football Promotions ...                    11
# Balance ...                                10
# ...
